# %%
import pandas as pd

# %%
import io

data = """
Order_ID,Order_Date,Customer_ID,Region,Product_Category,Product_Name,Quantity,Unit_Price,Discount,Payment_Method
1001,2024-01-15,CUST-882,North,Electronics,Wireless Mouse,2,25.50,0.0,Credit Card
1002,2024-01-16,CUST-411,West,Furniture,Office Chair,1,150.00,0.1,PayPal
1003,2024-01-18,CUST-905,East,Electronics,USB Cable,5,8.99,0.0,Credit Card
1004,2024-01-20,CUST-112,South,Office Supplies,Notebook 3-Pack,3,12.00,0.05,Credit Card
1005,2024-01-21,CUST-882,North,Electronics,Wireless Mouse,1,25.50,0.0,Debit Card
1006,2024-01-25,CUST-654,West,Furniture,Desk Lamp,2,45.00,0.15,Cash
1007,2024-01-28,CUST-331,East,Electronics,27-inch Monitor,1,299.99,0.0,Credit Card
1008,2024-02-01,CUST-905,East,Office Supplies,Gel Pens 10-Pack,10,5.50,0.0,PayPal
1009,2024-02-03,CUST-204,South,Furniture,Office Chair,4,150.00,0.2,Credit Card
1010,2024-02-05,CUST-771,North,Electronics,Mechanical Keyboard,1,85.00,0.0,Debit Card
1011,2024-02-10,CUST-112,South,Office Supplies,,2,15.00,0.0,Credit Card
1012,2024-02-12,CUST-559,West,Electronics,Wireless Mouse,3,25.50,0.05,PayPal
1013,2024-02-15,CUST-882,North,Furniture,Standing Desk,1,450.00,0.1,Credit Card
1014,2024-02-18,CUST-331,East,Electronics,USB Cable,2,8.99,0.0,Debit Card
1015,2024-02-22,CUST-411,West,Office Supplies,Stapler,1,11.25,0.0,Cash
"""

df = pd.read_csv(io.StringIO(data.strip()))

# Convert Order_Date to proper datetime format
df['Order_Date'] = pd.to_datetime(df['Order_Date'])

# %%
df
# Out:
#     Order_ID Order_Date Customer_ID Region Product_Category  \
# 0       1001 2024-01-15    CUST-882  North      Electronics
# 1       1002 2024-01-16    CUST-411   West        Furniture
# 2       1003 2024-01-18    CUST-905   East      Electronics
# 3       1004 2024-01-20    CUST-112  South  Office Supplies
# 4       1005 2024-01-21    CUST-882  North      Electronics
# 5       1006 2024-01-25    CUST-654   West        Furniture
# 6       1007 2024-01-28    CUST-331   East      Electronics
# 7       1008 2024-02-01    CUST-905   East  Office Supplies
# 8       1009 2024-02-03    CUST-204  South        Furniture
# 9       1010 2024-02-05    CUST-771  North      Electronics
# 10      1011 2024-02-10    CUST-112  South  Office Supplies
# 11      1012 2024-02-12    CUST-559   West      Electronics
# 12      1013 2024-02-15    CUST-882  North        Furniture
# 13      1014 2024-02-18    CUST-331   East      Electronics
# 14      1015 2024-02-22    CUST-411   West  Office Supplies
#
#            Product_Name  Quantity  Unit_Price  Discount Payment_Method
# 0        Wireless Mouse         2       25.50      0.00    Credit Card
# 1          Office Chair         1      150.00      0.10         PayPal
# 2             USB Cable         5        8.99      0.00    Credit Card
# 3       Notebook 3-Pack         3       12.00      0.05    Credit Card
# 4        Wireless Mouse         1       25.50      0.00     Debit Card
# 5             Desk Lamp         2       45.00      0.15           Cash
# 6       27-inch Monitor         1      299.99      0.00    Credit Card
# 7      Gel Pens 10-Pack        10        5.50      0.00         PayPal
# 8          Office Chair         4      150.00      0.20    Credit Card
# 9   Mechanical Keyboard         1       85.00      0.00     Debit Card
# 10                  NaN         2       15.00      0.00    Credit Card
# 11       Wireless Mouse         3       25.50      0.05         PayPal
# 12        Standing Desk         1      450.00      0.10    Credit Card
# 13            USB Cable         2        8.99      0.00     Debit Card
# 14              Stapler         1       11.25      0.00           Cash

# %%
df.columns = df.columns.str.lower()

# %%
df
# Out:
#     order_id order_date customer_id region product_category  \
# 0       1001 2024-01-15    CUST-882  North      Electronics
# 1       1002 2024-01-16    CUST-411   West        Furniture
# 2       1003 2024-01-18    CUST-905   East      Electronics
# 3       1004 2024-01-20    CUST-112  South  Office Supplies
# 4       1005 2024-01-21    CUST-882  North      Electronics
# 5       1006 2024-01-25    CUST-654   West        Furniture
# 6       1007 2024-01-28    CUST-331   East      Electronics
# 7       1008 2024-02-01    CUST-905   East  Office Supplies
# 8       1009 2024-02-03    CUST-204  South        Furniture
# 9       1010 2024-02-05    CUST-771  North      Electronics
# 10      1011 2024-02-10    CUST-112  South  Office Supplies
# 11      1012 2024-02-12    CUST-559   West      Electronics
# 12      1013 2024-02-15    CUST-882  North        Furniture
# 13      1014 2024-02-18    CUST-331   East      Electronics
# 14      1015 2024-02-22    CUST-411   West  Office Supplies
#
#            product_name  quantity  unit_price  discount payment_method
# 0        Wireless Mouse         2       25.50      0.00    Credit Card
# 1          Office Chair         1      150.00      0.10         PayPal
# 2             USB Cable         5        8.99      0.00    Credit Card
# 3       Notebook 3-Pack         3       12.00      0.05    Credit Card
# 4        Wireless Mouse         1       25.50      0.00     Debit Card
# 5             Desk Lamp         2       45.00      0.15           Cash
# 6       27-inch Monitor         1      299.99      0.00    Credit Card
# 7      Gel Pens 10-Pack        10        5.50      0.00         PayPal
# 8          Office Chair         4      150.00      0.20    Credit Card
# 9   Mechanical Keyboard         1       85.00      0.00     Debit Card
# 10                  NaN         2       15.00      0.00    Credit Card
# 11       Wireless Mouse         3       25.50      0.05         PayPal
# 12        Standing Desk         1      450.00      0.10    Credit Card
# 13            USB Cable         2        8.99      0.00     Debit Card
# 14              Stapler         1       11.25      0.00           Cash

# %%
df[(df['unit_price'] == 25) & (df['region'] == 'North')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'unit_price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 df.loc[(df['unit_price'] == 25) & (df['region'] == 'North')]
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4374
#    4375         if is_single_key:
#    4376             if self.columns.nlevels > 1:
#    4377                 return self._getitem_multilevel(key)
# -> 4378             indexer = self.columns.get_loc(key)
#    4379             if is_integer(indexer):
#    4380                 indexer = [indexer]
#    4381         else:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'unit_price'
